# %%
import requests
from bs4 import BeautifulSoup
import time

# %%
payload = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.102 Safari/537.36',
'Cookie': 'Hm_lvt_78c58f01938e4d85eaf619eae71b4ed1=1588951133,1588956015; userid=5099556; u_name=musicx; escapename=musicx; user=%3D; ticket=ce48e8a79fb0824e91e083a206d15234; reviewJump=nojump; searchGuide=sg; usersurvey=1; v=Ati9ZpgCM9ua7h9fFfcbjqCGqQ1pwTxKniUQzxLJJJPGrXb7utEM2-414Flh'}

# %%
ua = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.102 Safari/537.36'}

# %%
r=requests.get('http://basic.10jqka.com.cn/300783', headers=ua)
r.encoding='gbk'
r.text
# Out:
# '<!DOCTYPE HTML>\n<html>\n<head>\n\t    <title>三只松鼠(300783) 最新动态_F10_同花顺金融服务网</title>\n\t<meta http-equiv="X-UA-Compatible" content="IE=EmulateIE7;IE=9"/>\n\t<meta http-equiv="Content-Type" content="text/html; charset=gbk"/>\n\t<meta name="keywords" content="三只松鼠最新动态,三只松鼠公司概况,三只松鼠财务分析,三只松鼠股东研究,三只松鼠股本结构,三只松鼠公司大事,三只松鼠分红融资"/>\n\t<meta name="description" content="暂无"/>\n\t\t<script type="text/javascript" src="//s.thsi.cn/js/chameleon/chameleon.min.1600217.js"></script> <script src="//s.thsi.cn/js/m/common/bridge.js" type="text/javascript"  crossorigin></script>\n\t\t<script id="monitor-script" api_key="ths_f10" src="//s.thsi.cn/js/common/monitor/1.0/monitor.min.js" crossorigin></script>\n\t<script>\n\t\ttry{\n\t\t\tfeMonitor.setConfig(\n\t\t\t\t{\n\t\t\t\tslientDev:false,//开发环境(localhost)是否发送报错请求，默认不发送为true\n\t\t\t\tsampleRate:0.1, //采样率,可设置0-1之间，越小采集的频率越低\n\t\t\t\tisCollectPerformance:true, //是否采集性能\n\t\t\t\ttitle:\'pc-F10\'\n\t\t\t\t}\n\t\t\t);\n\t\t}catch(e){\n\n\t\t}\n\t</script>\n\t
# ...

# %%
soup = BeautifulSoup(r.text, 'lxml')
soup
# Out:
# <!DOCTYPE HTML>
# <html>
# <head>
# <title>三只松鼠(300783) 最新动态_F10_同花顺金融服务网</title>
# <meta content="IE=EmulateIE7;IE=9" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="三只松鼠最新动态,三只松鼠公司概况,三只松鼠财务分析,三只松鼠股东研究,三只松鼠股本结构,三只松鼠公司大事,三只松鼠分红融资" name="keywords"/>
# <meta content="暂无" name="description"/>
# <script src="//s.thsi.cn/js/chameleon/chameleon.min.1600217.js" type="text/javascript"></script> <script crossorigin="" src="//s.thsi.cn/js/m/common/bridge.js" type="text/javascript"></script>
# <script api_key="ths_f10" crossorigin="" id="monitor-script" src="//s.thsi.cn/js/common/monitor/1.0/monitor.min.js"></script>
# <script>
# 		try{
# 			feMonitor.setConfig(
# 				{
# 				slientDev:false,//开发环境(localhost)是否发送报错请求，默认不发送为true
# 				sampleRate:0.1, //采样率,可设置0-1之间，越小采集的频率越低
# 				isCollectPerformance:true, //是否采集性能
# 				title:'pc-F10'
# 				}
# 			);
# 		}catch(e){
#
# 		}
# 	</script>
# <style>
# ...

# %%
concept= soup.find('div', class_='newconcept')
concept.attrs
# Out:
# {'class': ['f14', 'newconcept'], 'cont': 'yes', 'style': 'overflow: hidden;'}

# %%
soup.find('span', class_='core-view-text').text.strip()
# Out:
# '国内知名的休闲零食电商品牌，主营坚果、干果系列产品'

# %%
soup.find('span', class_='main-bussiness-text').text.strip()
# Out:
# '自有品牌休闲食品的研发、检测、分装及销售'

# %%
conc = concept.find_all('a', class_='newtaid')
conc[0].text
# Out:
# '人造肉'

# %%
conc
# Out:
# [<a class="newtaid" href="./concept.html?cid=308517#ifind" ifjump="1" newtaid="f10_zxdt_code-gsgy-r2c1-clickcontent-atgn-308517" title="此概念在该股票中走势贴合度排名第一">人造肉<em class="ccept_top1"></em></a>,
#  <a class="newtaid" href="./concept.html?cid=308630#ifind" ifjump="1" newtaid="f10_zxdt_code-gsgy-r2c1-clickcontent-atgn-308630" title="此概念在该股票中走势贴合度排名第二">网红经济<em class="ccept_top2"></em></a>,
#  <a class="newtaid" href="./concept.html?cid=300023#ifind" ifjump="1" newtaid="f10_zxdt_code-gsgy-r2c1-clickcontent-atgn-300023" title="此概念在该股票中走势贴合度排名第三">食品安全<em class="ccept_top3"></em></a>,
#  <a class="newtaid" href="./concept.html?cid=308588#emerging" ifjump="1" newtaid="f10_zxdt_code-gsgy-r2c1-clickcontent-atgn-308588">宠物经济</a>,
#  <a class="newtaid" href="./concept.html?cid=300175#emerging" ifjump="1" newtaid="f10_zxdt_code-gsgy-r2c1-clickcontent-atgn-300175">大消费</a>,
# ...

# %%
'title' in conc[3]
# Out:
# False

# %%
conc[3].em is None
# Out:
# True

# %%
cpt_text = []
for cpt in concept.find_all('a', class_='newtaid') :
    if cpt.em is not None:
        cpt_text.append('{}*'.format(cpt.text))
    elif '详情' not in cpt.text:
        cpt_text.append(cpt.text)

# %%
cpt_text
# Out:
# ['人造肉*', '网红经济*', '食品安全*', '宠物经济', '大消费', '深股通']

# %%
stocks = []
with open('c:\\Users\\mUSicX\\Documents\\20200916.txt', 'r') as f:
    while True:
        l = f.readline().strip()
        if not l:
            break
        stocks.append(l)
    
stocks[:10]
# Out:
# ['code',
#  '000001',
#  '000002',
#  '000004',
#  '000005',
#  '000006',
#  '000007',
#  '000008',
#  '000009',
#  '000010']

# %%
ff = open('c:\\Users\\mUSicX\\Documents\\crawl20200921.txt', 'w')
for s in stocks[1:]:
    try:
        r=requests.get('http://basic.10jqka.com.cn/{}'.format(s), headers=ua)
        r.encoding='gbk'
        soup = BeautifulSoup(r.text, 'lxml')
        item = []
        item.append(s)
        core = soup.find('span', class_='core-view-text')
        if core is not None:
            item.append(core.text.strip())
        else:
            item.append('无亮点')
        main = soup.find('span', class_='main-bussiness-text')
        if main is not None:
            item.append(main.text.strip())
        else:
            item.append('无主营')
        concept= soup.find('div', class_='newconcept')
        cpt_text = []
        for cpt in concept.find_all('a', class_='newtaid') :
            if cpt.em is not None:
                cpt_text.append('{}*'.format(cpt.text))
            elif '详情' not in cpt.text:
                cpt_text.append(cpt.text)
        if len(cpt_text) > 0:
            item.append(','.join(cpt_text))
        else:
            item.append('无概念')
        line = '\t'.join(item)
    except:
        print('{} error'.format(s))
        continue
    ff.write(line)
    ff.write('\n')
    ff.flush()
    print(line)
    time.sleep(1.5)
    
ff.close()
# Out:
# 000001	卓越领先的智能化零售银行	经有关监管机构批准的各项商业银行业务	MSCI概念,标普道琼斯A股,融资融券,深股通
# 000002	中国最响亮的品牌地产开发商	房地产开发和物业服务	REITs*,冰雪产业*,体育产业*,MSCI概念,标普道琼斯A股,超级品牌,融资融券,深股通,猪肉,装配式建筑
# 000004	主营业务为移动互联网游戏的运营及相关服务	移动互联网安全业务及移动互联网游戏运营相关服务。	车联网*,壳资源*,网络安全*,5G,电力物联网,网络游戏
# 000005	中外合资股份制企业,首批在深圳证券交易所上市的公司之一	绿色低碳城市社区建设相关的服务业务	广东自贸区*,固废处理*
# 000006	以房地产开发、住房租赁、物业管理为主业的国有控股公司	从事房地产开发与销售	深圳国资改革*,粤港澳大湾区*,标普道琼斯A股,融资融券,深股通
# 000007	物业管理和房屋租赁业稳定发展	物业管理和房屋租赁业等	粤港澳大湾区*,口罩*,独角兽概念*,金融科技
# 000008	领先的轨道交通运营安全维护领域系统化解决方案提供商	专业致力于为轨道交通安全运营提供监测、检测、维修、保养设备和服务及整体解决方案。	PPP概念*,高铁*,央企国资改革*,标普道琼斯A股,工业4.0,轨道交通,机器人概念,融资融券,深股通,腾讯概念,新基建,云计算
# 000009	投资控股型企业，搭建了多产业、多层面、多形式的投资平台	新能源、新材料及其它高新技术产业、生物医药业、房地产业以及其他行业	新三板精选层概念*,宁德时代概念*,石墨烯*,标普道琼斯A股,参股新三板,充电桩,创投,分拆上市意愿,黄金概念,军工,口罩,融资融券,深股通,生物医药,土地流转,稀土永磁,小金属概念,芯片概念,新能源汽车,钴,锂电池
# 000010	公司园林绿化业务资质可比肩国内一线企业，具有较强的综合竞争力	从事苗木种植、园林绿化工程施工和养护为一体的综合性园林服务。	天然气*,摘帽
# 000011	深圳国资委控股的房地产开发商	从事房地产开发经营，兼营物业管理、房屋租赁、出租车客运、餐饮服务等	深圳国资改革*,粤港澳大湾区*,免税店*
# ...

# %%
high = {}
desc = {}
cnpt = {}

with open('c:\\Users\\mUSicX\\Downloads\\crawl.txt', encoding='utf-8') as f:
    while True:
        line = f.readline()
        if not line:
            break
        parts = line.split('\t')
        high[parts[0]] = parts[1]
        desc[parts[0]] = parts[2]
        cnpt[parts[0]] = parts[3]

# %%
with open("c:\\Users\\mUSicX\\Documents\\股票相关\\ths_highlight.txt", 'w', encoding='gbk') as f:
    for k, v in high.items():
        mkt = '1' if k.startswith('6') else '0'
        f.write('{}|{}|{}|0\n'.format(mkt, k, v))

# %%
with open("c:\\Users\\mUSicX\\Documents\\股票相关\\ths_desc.txt", 'w', encoding='gbk') as f:
    for k, v in desc.items():
        mkt = '1' if k.startswith('6') else '0'
        f.write('{}|{}|{}|0\n'.format(mkt, k, v))

# %%
with open("c:\\Users\\mUSicX\\Documents\\股票相关\\ths_concept.txt", 'w', encoding='gbk') as f:
    for k, v in cnpt.items():
        mkt = '1' if k.startswith('6') else '0'
        f.write('{}|{}|{}|0\n'.format(mkt, k, v.strip()))
